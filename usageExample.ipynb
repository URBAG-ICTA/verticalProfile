# %%
we = WrfEvaluation()

we.compareVerticalProfile("./input/radiosonde/"+"16070200.TXT", "../WRFout1/"+"wrfout_d03_2016-07-02_00.nc", 0, './outputs/16070200', True, False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-14d14bf30bcb> in <module>
#       2 we = WrfEvaluation()
#       3
# ----> 4 we.compareVerticalProfile("./input/radiosonde/"+"16070200.TXT", "./input/wrfSimulation/"+"wrfout_d03_2016-07-02_00.nc", 0, './outputs/16070200', True, False)
#
# ~\Projects\verticalProfile\src\WrfEvaluation.py in compareVerticalProfile(self, radiosondatgeFile, wrf_file, wrf_cell_Time, outputFile, plot, save)
#      30         startTime = time.time()
#      31         call = inspect.currentframe().f_code.co_name+"('"+radiosondatgeFile+"', '"+wrf_file+"', "+str(wrf_cell_Time)+", '"+outputFile+"', "+str(plot)+", "+str(save)+")"
# ---> 32         wrf_file = Dataset(wrf_file, "r", format="NETCDF3")
#      33         self.dataFrame = self.getColumnsFromRadiosondatgeFile( radiosondatgeFile, self.columnsFromRadiosondatge)
# ...

# %%
we.compareVerticalProfile("./input/radiosonde/"+"16070212.TXT", "../WRFout1/"+"wrfout_d03_2016-07-02_00.nc", 12, './outputs/16070200', True, True)
# Out:
# {'Temp mean square error': 1.0800378693134687,
#  'difference of PBL in metters': -457.0238834951457,
#  'call to repeat calculations': "compareVerticalProfile('./input/radiosonde/16070212.TXT', '../WRFout1/wrfout_d03_2016-07-02_00.nc', 12, './outputs/16070200', True, True)",
#  'execution time in seconds': 1.822866678237915}
